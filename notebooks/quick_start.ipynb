# %% [markdown]
# # Dance Generation System - Quick Start
#
# This notebook demonstrates how to use the dance generation system to train models and generate dance sequences.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

import torch
import numpy as np
import matplotlib.pyplot as plt
from src.configs.config import get_default_config
from src.models.models import create_model
from src.data.dataset import create_dance_data_module
from src.utils.utils import set_seed, get_device
from src.utils.sampling import create_sampler, DanceVisualizer
